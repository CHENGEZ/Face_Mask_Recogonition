# %%
from google.colab import drive
drive.mount('/content/drive')
import sys
sys.path.append("/content/drive/MyDrive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd drive/MyDrive/FRCNN/COMP5214_FRCNN-master
# Out:
# /content/drive/MyDrive/FRCNN/COMP5214_FRCNN-master

# %%
# !python measure_map.py -p testMergedLabels.txt -o simple --model_path resnet50_result/model_frcnn_0039.hdf5
# Out:
# {0: 'no mask', 1: 'cloth', 2: 'N95', 3: 'surgical', 4: 'improper', 5: 'bg'}
# 2022-05-17 04:15:31.558385: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Loading weights from resnet50_result/model_frcnn_0039.hdf5
# Parsing annotation files
# idx=2041/197
# Elapsed time =  4.800170421600342
# [{'x1': 112, 'x2': 336, 'y1': 64, 'y2': 368, 'class': 'surgical', 'prob': 0.98146755}]
# [0.98146755]
# IoU = 0.7802904773777012
# surgical AP: 1.0
# mAP = 1.0
# 2/197
# Elapsed time =  0.7024331092834473
# [{'x1': 96, 'x2': 336, 'y1': 96, 'y2': 368, 'class': 'N95', 'prob': 0.99725914}]
# [0.99725914]
# IoU = 0.740403501676232
# surgical AP: 1.0
# N95 AP: 1.0
# mAP = 1.0
# 3/197
# Elapsed time =  0.6851553916931152
# [{'x1': 96, 'x2': 352, 'y1': 112, 'y2': 384, 'class': 'N95', 'prob': 0.9979911}]
# [0.9979911]
# IoU = 0.7009529300869326
# ...

# %%
# !python measure_map.py -p testMergedLabels.txt -o simple --model_path resnet50_result/model_frcnn_0034.hdf5
# Out:
# {0: 'no mask', 1: 'cloth', 2: 'N95', 3: 'surgical', 4: 'improper', 5: 'bg'}
# 2022-05-17 04:18:13.781288: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Loading weights from resnet50_result/model_frcnn_0034.hdf5
# Parsing annotation files
# idx=2041/197
# Elapsed time =  4.643916368484497
# [{'x1': 112, 'x2': 352, 'y1': 64, 'y2': 384, 'class': 'surgical', 'prob': 0.9975223}]
# [0.9975223]
# IoU = 0.8505831326630223
# surgical AP: 1.0
# mAP = 1.0
# 2/197
# Elapsed time =  0.5678856372833252
# [{'x1': 96, 'x2': 320, 'y1': 80, 'y2': 352, 'class': 'N95', 'prob': 0.9989318}]
# [0.9989318]
# IoU = 0.7394958283894145
# surgical AP: 1.0
# N95 AP: 1.0
# mAP = 1.0
# 3/197
# Elapsed time =  0.5543346405029297
# [{'x1': 80, 'x2': 336, 'y1': 80, 'y2': 384, 'class': 'N95', 'prob': 0.9940764}]
# [0.9940764]
# IoU = 0.8063441047887351
# surgical AP: 1.0
# ...

# %%
# !python measure_map.py -p testMergedLabels.txt -o simple --model_path resnet50_result/model_frcnn_0029.hdf5
# Out:
# {0: 'no mask', 1: 'cloth', 2: 'N95', 3: 'surgical', 4: 'improper', 5: 'bg'}
# 2022-05-17 04:20:41.866308: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Loading weights from resnet50_result/model_frcnn_0029.hdf5
# Parsing annotation files
# idx=2041/197
# Elapsed time =  4.510942697525024
# [{'x1': 112, 'x2': 352, 'y1': 64, 'y2': 384, 'class': 'surgical', 'prob': 0.99693906}]
# [0.99693906]
# IoU = 0.8505831326630223
# surgical AP: 1.0
# mAP = 1.0
# 2/197
# Elapsed time =  0.6262423992156982
# [{'x1': 96, 'x2': 320, 'y1': 80, 'y2': 352, 'class': 'N95', 'prob': 0.99787116}]
# [0.99787116]
# IoU = 0.7394958283894145
# surgical AP: 1.0
# N95 AP: 1.0
# mAP = 1.0
# 3/197
# Elapsed time =  0.5768251419067383
# [{'x1': 96, 'x2': 336, 'y1': 96, 'y2': 384, 'class': 'N95', 'prob': 0.99846774}]
# [0.99846774]
# IoU = 0.7817527261248293
# ...

# %%
# !python measure_map.py -p testMergedLabels.txt -o simple --model_path resnet50_result/model_frcnn_0024.hdf5
# Out:
# {0: 'no mask', 1: 'cloth', 2: 'N95', 3: 'surgical', 4: 'improper', 5: 'bg'}
# 2022-05-17 04:23:11.856791: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Loading weights from resnet50_result/model_frcnn_0024.hdf5
# Parsing annotation files
# idx=2041/197
# Elapsed time =  4.454034805297852
# [{'x1': 112, 'x2': 336, 'y1': 64, 'y2': 368, 'class': 'surgical', 'prob': 0.99533844}]
# [0.99533844]
# IoU = 0.7802904773777012
# surgical AP: 1.0
# mAP = 1.0
# 2/197
# Elapsed time =  0.4772224426269531
# [{'x1': 96, 'x2': 352, 'y1': 64, 'y2': 352, 'class': 'N95', 'prob': 0.9929443}]
# [0.9929443]
# IoU = 0.8608090511391387
# surgical AP: 1.0
# N95 AP: 1.0
# mAP = 1.0
# 3/197
# Elapsed time =  0.49602341651916504
# [{'x1': 96, 'x2': 352, 'y1': 80, 'y2': 368, 'class': 'N95', 'prob': 0.9994311}]
# [0.9994311]
# IoU = 0.785715076455883
# surgical AP: 1.0
# ...

# %%
# !python measure_map.py -p testMergedLabels.txt -o simple --model_path resnet50_result/model_frcnn_0019.hdf5
# Out:
# {0: 'no mask', 1: 'cloth', 2: 'N95', 3: 'surgical', 4: 'improper', 5: 'bg'}
# 2022-05-17 04:25:23.308149: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Loading weights from resnet50_result/model_frcnn_0019.hdf5
# Parsing annotation files
# idx=2041/197
# Elapsed time =  4.551967620849609
# [{'x1': 112, 'x2': 352, 'y1': 80, 'y2': 384, 'class': 'surgical', 'prob': 0.97218907}]
# [0.97218907]
# IoU = 0.8075631906148995
# surgical AP: 1.0
# mAP = 1.0
# 2/197
# Elapsed time =  0.36546969413757324
# [{'x1': 96, 'x2': 336, 'y1': 80, 'y2': 352, 'class': 'N95', 'prob': 0.9991755}]
# [0.9991755]
# IoU = 0.7923169589886585
# surgical AP: 1.0
# N95 AP: 1.0
# mAP = 1.0
# 3/197
# Elapsed time =  0.38456058502197266
# [{'x1': 80, 'x2': 320, 'y1': 64, 'y2': 352, 'class': 'N95', 'prob': 0.9992761}]
# [0.9992761]
# IoU = 0.8201763064977035
# ...

# %%
# !python measure_map.py -p testMergedLabels.txt -o simple --model_path resnet50_result/model_frcnn_0014.hdf5
# Out:
# {0: 'no mask', 1: 'cloth', 2: 'N95', 3: 'surgical', 4: 'improper', 5: 'bg'}
# 2022-05-17 04:27:14.262807: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Loading weights from resnet50_result/model_frcnn_0014.hdf5
# Parsing annotation files
# idx=2041/197
# Elapsed time =  4.371098041534424
# [{'x1': 96, 'x2': 336, 'y1': 64, 'y2': 384, 'class': 'surgical', 'prob': 0.99940217}]
# [0.99940217]
# IoU = 0.8531145480443802
# surgical AP: 1.0
# mAP = 1.0
# 2/197
# Elapsed time =  0.40654945373535156
# [{'x1': 96, 'x2': 336, 'y1': 64, 'y2': 352, 'class': 'N95', 'prob': 0.99859554}]
# [0.99859554]
# IoU = 0.8079156772495029
# surgical AP: 1.0
# N95 AP: 1.0
# mAP = 1.0
# 3/197
# Elapsed time =  0.4144632816314697
# [{'x1': 80, 'x2': 336, 'y1': 80, 'y2': 352, 'class': 'N95', 'prob': 0.9995509}]
# [0.9995509]
# IoU = 0.7714359219646634
# ...

# %%
# !python measure_map.py -p testMergedLabels.txt -o simple --model_path resnet50_result/model_frcnn_0009.hdf5
# Out:
# {0: 'no mask', 1: 'cloth', 2: 'N95', 3: 'surgical', 4: 'improper', 5: 'bg'}
# 2022-05-17 04:29:11.975883: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Loading weights from resnet50_result/model_frcnn_0009.hdf5
# Parsing annotation files
# idx=2041/197
# Elapsed time =  4.462013483047485
# [{'x1': 112, 'x2': 320, 'y1': 80, 'y2': 384, 'class': 'surgical', 'prob': 0.9981376}]
# [0.9981376]
# IoU = 0.7058208645275041
# surgical AP: 1.0
# mAP = 1.0
# 2/197
# Elapsed time =  0.35274600982666016
# [{'x1': 80, 'x2': 336, 'y1': 128, 'y2': 368, 'class': 'N95', 'prob': 0.9977323}]
# [0.9977323]
# IoU = 0.6918796075438721
# surgical AP: 1.0
# N95 AP: 1.0
# mAP = 1.0
# 3/197
# Elapsed time =  0.34169602394104004
# [{'x1': 64, 'x2': 352, 'y1': 128, 'y2': 368, 'class': 'N95', 'prob': 0.993129}]
# [0.993129]
# IoU = 0.6276035446485209
# surgical AP: 1.0
# ...

# %%
# !python measure_map.py -p testMergedLabels.txt -o simple --model_path resnet50_result/model_frcnn_0004.hdf5
# Out:
# {0: 'no mask', 1: 'cloth', 2: 'N95', 3: 'surgical', 4: 'improper', 5: 'bg'}
# 2022-05-17 04:30:58.336333: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Loading weights from resnet50_result/model_frcnn_0004.hdf5
# Parsing annotation files
# idx=2041/197
# Elapsed time =  4.268462657928467
# [{'x1': 112, 'x2': 368, 'y1': 48, 'y2': 384, 'class': 'surgical', 'prob': 0.998804}]
# [0.998804]
# IoU = 0.8425100473928284
# surgical AP: 1.0
# mAP = 1.0
# 2/197
# Elapsed time =  0.3464927673339844
# [{'x1': 112, 'x2': 320, 'y1': 96, 'y2': 352, 'class': 'N95', 'prob': 0.99025553}]
# [0.99025553]
# IoU = 0.6462820685083959
# surgical AP: 1.0
# N95 AP: 1.0
# mAP = 1.0
# 3/197
# Elapsed time =  0.3434112071990967
# [{'x1': 112, 'x2': 320, 'y1': 80, 'y2': 368, 'class': 'N95', 'prob': 0.9927134}]
# [0.9927134]
# IoU = 0.7788679621389671
# surgical AP: 1.0
# ...

# %%
# !python measure_map.py -p testMergedLabels.txt -o simple --model_path resnet50_result/model_frcnn_0000.hdf5
