# %% [markdown]
# # Google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
import sys
sys.path.append("/content/drive/MyDrive")
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/FRCNN/COMP5214_FRCNN-master
# Out:
# /content/drive/MyDrive/FRCNN/COMP5214_FRCNN-master

# %% [markdown]
# # Resnet50

# %%
# !python train_frcnn.py -o simple -p ./MergedLabels.txt --network resnet50 --output_weight_path ./new_resnet_result/model_frcnn.hdf5 --input_weight_path ./resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# Out:
# Parsing annotation files
# idx=6003Training images per class:
# {'N95': 930,
#  'bg': 0,
#  'cloth': 1993,
#  'improper': 644,
#  'no mask': 686,
#  'surgical': 1750}
# Num classes (including bg) = 6
# Config has been written to config.pickle, and can be loaded when testing to ensure correct results
# Num train samples 5923
# 2022-05-16 17:46:23.338857: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# loading weights from ./resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Starting training
# Epoch 1/40
# ...

# %%
# !/opt/bin/nvidia-smi
# Out:
# Mon May 16 16:02:59 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P8     8W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...
