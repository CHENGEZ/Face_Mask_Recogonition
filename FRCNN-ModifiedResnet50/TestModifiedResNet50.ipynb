# %%
from google.colab import drive
drive.mount('/content/drive')
import sys
sys.path.append("/content/drive/MyDrive")
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/FRCNN/COMP5214_FRCNN-master
# Out:
# /content/drive/MyDrive/FRCNN/COMP5214_FRCNN-master

# %%
# !python measure_map.py -p testMergedLabels.txt -o simple --model_path new_resnet_result/model_frcnn_0039.hdf5
# Out:
# {0: 'no mask', 1: 'cloth', 2: 'N95', 3: 'surgical', 4: 'improper', 5: 'bg'}
# 2022-05-17 05:25:48.169946: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Loading weights from new_resnet_result/model_frcnn_0039.hdf5
# Parsing annotation files
# idx=2041/197
# Elapsed time =  11.9470694065094
# [{'x1': 112, 'x2': 336, 'y1': 80, 'y2': 384, 'class': 'surgical', 'prob': 0.99730057}]
# [0.99730057]
# IoU = 0.759480119081296
# surgical AP: 1.0
# mAP = 1.0
# 2/197
# Elapsed time =  0.6138632297515869
# [{'x1': 96, 'x2': 320, 'y1': 96, 'y2': 368, 'class': 'N95', 'prob': 0.9973392}]
# [0.9973392]
# IoU = 0.6923802286112775
# surgical AP: 1.0
# N95 AP: 1.0
# mAP = 1.0
# 3/197
# Elapsed time =  0.6256732940673828
# [{'x1': 112, 'x2': 336, 'y1': 96, 'y2': 400, 'class': 'N95', 'prob': 0.9996153}]
# [0.9996153]
# IoU = 0.6981816988636889
# surgical AP: 1.0
# ...

# %%
# !python measure_map.py -p testMergedLabels.txt -o simple --model_path new_resnet_result/model_frcnn_0034.hdf5
# Out:
# {0: 'no mask', 1: 'cloth', 2: 'N95', 3: 'surgical', 4: 'improper', 5: 'bg'}
# 2022-05-17 05:29:40.516425: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Loading weights from new_resnet_result/model_frcnn_0034.hdf5
# Parsing annotation files
# idx=2041/197
# Elapsed time =  4.9414381980896
# [{'x1': 112, 'x2': 352, 'y1': 64, 'y2': 368, 'class': 'surgical', 'prob': 0.9953402}]
# [0.9953402]
# IoU = 0.8303128088546219
# surgical AP: 1.0
# mAP = 1.0
# 2/197
# Elapsed time =  0.6689257621765137
# [{'x1': 96, 'x2': 336, 'y1': 96, 'y2': 368, 'class': 'N95', 'prob': 0.998298}]
# [0.998298]
# IoU = 0.740403501676232
# surgical AP: 1.0
# N95 AP: 1.0
# mAP = 1.0
# 3/197
# Elapsed time =  0.7096991539001465
# [{'x1': 96, 'x2': 336, 'y1': 96, 'y2': 368, 'class': 'N95', 'prob': 0.9923097}]
# [0.9923097]
# IoU = 0.7864962459282099
# surgical AP: 1.0
# ...

# %%
# !python measure_map.py -p testMergedLabels.txt -o simple --model_path new_resnet_result/model_frcnn_0029.hdf5
# Out:
# {0: 'no mask', 1: 'cloth', 2: 'N95', 3: 'surgical', 4: 'improper', 5: 'bg'}
# 2022-05-17 05:32:29.941382: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Loading weights from new_resnet_result/model_frcnn_0029.hdf5
# Parsing annotation files
# idx=2041/197
# Elapsed time =  4.653747320175171
# [{'x1': 112, 'x2': 352, 'y1': 64, 'y2': 368, 'class': 'surgical', 'prob': 0.9984125}, {'x1': 384, 'x2': 416, 'y1': 272, 'y2': 400, 'class': 'no mask', 'prob': 0.86106783}, {'x1': 384, 'x2': 416, 'y1': 32, 'y2': 112, 'class': 'no mask', 'prob': 0.7356378}]
# [0.9984125  0.86106783 0.7356378 ]
# IoU = 0.8303128088546219
# surgical AP: 1.0
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# no mask AP: nan
# mAP = nan
# 2/197
# ...

# %%
# !python measure_map.py -p testMergedLabels.txt -o simple --model_path new_resnet_result/model_frcnn_0024.hdf5
# Out:
# {0: 'no mask', 1: 'cloth', 2: 'N95', 3: 'surgical', 4: 'improper', 5: 'bg'}
# 2022-05-17 05:35:19.961949: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Loading weights from new_resnet_result/model_frcnn_0024.hdf5
# Parsing annotation files
# idx=2041/197
# Elapsed time =  4.610971689224243
# [{'x1': 112, 'x2': 320, 'y1': 64, 'y2': 368, 'class': 'surgical', 'prob': 0.9898032}]
# [0.9898032]
# IoU = 0.724555443279294
# surgical AP: 1.0
# mAP = 1.0
# 2/197
# Elapsed time =  0.573883056640625
# [{'x1': 96, 'x2': 336, 'y1': 64, 'y2': 352, 'class': 'N95', 'prob': 0.99594265}]
# [0.99594265]
# IoU = 0.8079156772495029
# surgical AP: 1.0
# N95 AP: 1.0
# mAP = 1.0
# 3/197
# Elapsed time =  0.6144332885742188
# [{'x1': 96, 'x2': 336, 'y1': 80, 'y2': 384, 'class': 'N95', 'prob': 0.99364835}]
# [0.99364835]
# IoU = 0.8250935048676089
# ...

# %%
# !python measure_map.py -p testMergedLabels.txt -o simple --model_path new_resnet_result/model_frcnn_0019.hdf5
# Out:
# {0: 'no mask', 1: 'cloth', 2: 'N95', 3: 'surgical', 4: 'improper', 5: 'bg'}
# 2022-05-17 05:37:55.145391: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Loading weights from new_resnet_result/model_frcnn_0019.hdf5
# Parsing annotation files
# idx=2041/197
# Elapsed time =  4.600927352905273
# ...

# %%
# !python measure_map.py -p testMergedLabels.txt -o simple --model_path new_resnet_result/model_frcnn_0014.hdf5
# Out:
# {0: 'no mask', 1: 'cloth', 2: 'N95', 3: 'surgical', 4: 'improper', 5: 'bg'}
# 2022-05-17 05:40:36.745252: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Loading weights from new_resnet_result/model_frcnn_0014.hdf5
# Parsing annotation files
# idx=2041/197
# Elapsed time =  4.6313841342926025
# [{'x1': 112, 'x2': 336, 'y1': 64, 'y2': 368, 'class': 'surgical', 'prob': 0.99462223}]
# [0.99462223]
# IoU = 0.7802904773777012
# surgical AP: 1.0
# mAP = 1.0
# 2/197
# Elapsed time =  0.5625925064086914
# [{'x1': 80, 'x2': 336, 'y1': 80, 'y2': 352, 'class': 'N95', 'prob': 0.99797577}]
# [0.99797577]
# IoU = 0.8451380895879024
# surgical AP: 1.0
# N95 AP: 1.0
# mAP = 1.0
# 3/197
# Elapsed time =  0.5455195903778076
# [{'x1': 80, 'x2': 336, 'y1': 80, 'y2': 368, 'class': 'N95', 'prob': 0.99374324}]
# [0.99374324]
# IoU = 0.8134514304753906
# ...

# %%
# !python measure_map.py -p testMergedLabels.txt -o simple --model_path new_resnet_result/model_frcnn_0009.hdf5
# Out:
# {0: 'no mask', 1: 'cloth', 2: 'N95', 3: 'surgical', 4: 'improper', 5: 'bg'}
# 2022-05-17 05:43:05.064266: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Loading weights from new_resnet_result/model_frcnn_0009.hdf5
# Parsing annotation files
# idx=2041/197
# Elapsed time =  4.585681438446045
# [{'x1': 112, 'x2': 336, 'y1': 64, 'y2': 384, 'class': 'surgical', 'prob': 0.99705446}]
# [0.99705446]
# IoU = 0.8000679835041955
# surgical AP: 1.0
# mAP = 1.0
# 2/197
# Elapsed time =  0.5520098209381104
# [{'x1': 96, 'x2': 288, 'y1': 112, 'y2': 368, 'class': 'N95', 'prob': 0.9983437}]
# [0.9983437]
# IoU = 0.5593575467754708
# surgical AP: 1.0
# N95 AP: 1.0
# mAP = 1.0
# 3/197
# Elapsed time =  0.4852299690246582
# [{'x1': 96, 'x2': 304, 'y1': 80, 'y2': 352, 'class': 'N95', 'prob': 0.99873227}]
# [0.99873227]
# IoU = 0.7355975197979134
# ...

# %%
# !python measure_map.py -p testMergedLabels.txt -o simple --model_path new_resnet_result/model_frcnn_0004.hdf5
# Out:
# {0: 'no mask', 1: 'cloth', 2: 'N95', 3: 'surgical', 4: 'improper', 5: 'bg'}
# 2022-05-17 05:45:20.770428: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Loading weights from new_resnet_result/model_frcnn_0004.hdf5
# Parsing annotation files
# idx=2041/197
# Elapsed time =  4.583598375320435
# [{'x1': 96, 'x2': 352, 'y1': 80, 'y2': 384, 'class': 'surgical', 'prob': 0.9853644}]
# [0.9853644]
# IoU = 0.8576767274252436
# surgical AP: 1.0
# mAP = 1.0
# 2/197
# Elapsed time =  0.4733316898345947
# [{'x1': 96, 'x2': 336, 'y1': 96, 'y2': 352, 'class': 'N95', 'prob': 0.9966331}]
# [0.9966331]
# IoU = 0.7457100790481491
# surgical AP: 1.0
# N95 AP: 1.0
# mAP = 1.0
# 3/197
# Elapsed time =  0.4182016849517822
# [{'x1': 96, 'x2': 336, 'y1': 96, 'y2': 384, 'class': 'N95', 'prob': 0.9965223}]
# [0.9965223]
# IoU = 0.7817527261248293
# surgical AP: 1.0
# ...

# %%
# !python measure_map.py -p testMergedLabels.txt -o simple --model_path resnet50_result/model_frcnn_0000.hdf5
