# %% [markdown]
# # google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
import sys
sys.path.append("/content/drive/MyDrive")
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/FRCNN/Keras-frcnn_
# Out:
# /content/drive/MyDrive/FRCNN/Keras-frcnn_

# %% [markdown]
# # Train the model (vgg16)

# %%
# !python train_frcnn.py -o simple -p ./MergedLabels.txt
# Out:
# Parsing annotation files
# idx=6003Training images per class:
# {'N95': 930,
#  'bg': 0,
#  'cloth': 1993,
#  'improper': 644,
#  'no mask': 686,
#  'surgical': 1750}
# Num classes (including bg) = 6
# Config has been written to config.pickle, and can be loaded when testing to ensure correct results
# Num train samples 5923
# 2022-05-13 10:03:30.197160: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# loading weights from vgg16_weights_tf_dim_ordering_tf_kernels.h5
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Starting training
# Epoch 1/40
# ...

# %%
# !python test_frcnn.py -p ./testdata/
# Out:
# {0: 'no mask', 1: 'cloth', 2: 'N95', 3: 'surgical', 4: 'improper', 5: 'bg'}
# 2022-05-13 14:10:23.135730: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 13.jpg
# Elapsed time = 5.949222564697266
# [('improper', 98.43952655792236)]
# 14.jpg
# Elapsed time = 0.9795575141906738
# [('surgical', 98.03512692451477)]
# 15.jpg
# Elapsed time = 0.9709436893463135
# [('improper', 98.70026111602783)]
# 16.jpg
# Elapsed time = 0.9351842403411865
# [('no mask', 99.05851483345032)]
# 23.jpg
# Elapsed time = 1.3165016174316406
# [('surgical', 92.38629341125488)]
# 24.jpg
# Elapsed time = 1.173058032989502
# [('improper', 98.97388815879822)]
