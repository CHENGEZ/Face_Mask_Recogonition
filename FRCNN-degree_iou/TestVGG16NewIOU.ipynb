# %%
from google.colab import drive
drive.mount('/content/drive')
import sys
sys.path.append("/content/drive/MyDrive")
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/FRCNN/COMP5214_FRCNN-master-new
# Out:
# /content/drive/MyDrive/FRCNN/COMP5214_FRCNN-master-new

# %%
# !python measure_map.py -p testMergedLabels.txt -o simple --model_path new_iou_result/model_frcnn_0039_newIOU.hdf5
# Out:
# {0: 'no mask', 1: 'cloth', 2: 'N95', 3: 'surgical', 4: 'improper', 5: 'bg'}
# 2022-05-17 09:02:49.248474: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Loading weights from new_iou_result/model_frcnn_0039_newIOU.hdf5
# Parsing annotation files
# idx=2041/197
# Elapsed time =  11.91101884841919
# [{'x1': 96, 'x2': 336, 'y1': 64, 'y2': 384, 'class': 'surgical', 'prob': 0.9809559}]
# [0.9809559]
# IoU = 0.8531145480443802
# surgical AP: 1.0
# mAP = 1.0
# 2/197
# Elapsed time =  0.3861732482910156
# [{'x1': 80, 'x2': 336, 'y1': 96, 'y2': 368, 'class': 'N95', 'prob': 0.9987674}]
# [0.9987674]
# IoU = 0.7882416698758877
# surgical AP: 1.0
# N95 AP: 1.0
# mAP = 1.0
# 3/197
# Elapsed time =  0.3749561309814453
# [{'x1': 96, 'x2': 336, 'y1': 80, 'y2': 384, 'class': 'N95', 'prob': 0.9939598}]
# [0.9939598]
# IoU = 0.8250935048676089
# ...

# %%
# !python measure_map.py -p testMergedLabels.txt -o simple --model_path new_iou_result/model_frcnn_0034.hdf5
# Out:
# {0: 'no mask', 1: 'cloth', 2: 'N95', 3: 'surgical', 4: 'improper', 5: 'bg'}
# 2022-05-17 09:05:54.370409: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Loading weights from new_iou_result/model_frcnn_0034.hdf5
# Parsing annotation files
# idx=2041/197
# Elapsed time =  2.75301456451416
# [{'x1': 96, 'x2': 336, 'y1': 64, 'y2': 384, 'class': 'surgical', 'prob': 0.99439234}]
# [0.99439234]
# IoU = 0.8531145480443802
# surgical AP: 1.0
# mAP = 1.0
# 2/197
# Elapsed time =  0.42679738998413086
# [{'x1': 80, 'x2': 336, 'y1': 80, 'y2': 368, 'class': 'N95', 'prob': 0.9963347}]
# [0.9963347]
# IoU = 0.8364227010418955
# surgical AP: 1.0
# N95 AP: 1.0
# mAP = 1.0
# 3/197
# Elapsed time =  0.42232847213745117
# [{'x1': 96, 'x2': 336, 'y1': 96, 'y2': 384, 'class': 'N95', 'prob': 0.9999207}]
# [0.9999207]
# IoU = 0.7817527261248293
# surgical AP: 1.0
# ...

# %%
# !python measure_map.py -p testMergedLabels.txt -o simple --model_path new_iou_result/model_frcnn_0029.hdf5
# Out:
# {0: 'no mask', 1: 'cloth', 2: 'N95', 3: 'surgical', 4: 'improper', 5: 'bg'}
# 2022-05-17 09:07:53.322395: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Loading weights from new_iou_result/model_frcnn_0029.hdf5
# Parsing annotation files
# idx=2041/197
# Elapsed time =  2.7246575355529785
# [{'x1': 128, 'x2': 352, 'y1': 64, 'y2': 384, 'class': 'surgical', 'prob': 0.9555437}]
# [0.9555437]
# IoU = 0.7943256534748936
# surgical AP: 1.0
# mAP = 1.0
# 2/197
# Elapsed time =  0.3839759826660156
# [{'x1': 96, 'x2': 336, 'y1': 80, 'y2': 368, 'class': 'N95', 'prob': 0.999172}]
# [0.999172]
# IoU = 0.7856604394315029
# surgical AP: 1.0
# N95 AP: 1.0
# mAP = 1.0
# 3/197
# Elapsed time =  0.43547797203063965
# [{'x1': 96, 'x2': 320, 'y1': 96, 'y2': 384, 'class': 'N95', 'prob': 0.99971527}]
# [0.99971527]
# IoU = 0.7887680670528718
# surgical AP: 1.0
# ...

# %%
# !python measure_map.py -p testMergedLabels.txt -o simple --model_path new_iou_result/model_frcnn_0024.hdf5
# Out:
# {0: 'no mask', 1: 'cloth', 2: 'N95', 3: 'surgical', 4: 'improper', 5: 'bg'}
# 2022-05-17 09:09:50.203256: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Loading weights from new_iou_result/model_frcnn_0024.hdf5
# Parsing annotation files
# idx=2041/197
# Elapsed time =  2.8249642848968506
# [{'x1': 112, 'x2': 384, 'y1': 64, 'y2': 384, 'class': 'surgical', 'prob': 0.94045967}]
# [0.94045967]
# IoU = 0.7625133981225987
# surgical AP: 1.0
# mAP = 1.0
# 2/197
# Elapsed time =  0.4420480728149414
# [{'x1': 96, 'x2': 336, 'y1': 112, 'y2': 368, 'class': 'N95', 'prob': 0.8753024}]
# [0.8753024]
# IoU = 0.6951465639209611
# surgical AP: 1.0
# N95 AP: 1.0
# mAP = 1.0
# 3/197
# Elapsed time =  0.44888782501220703
# [{'x1': 80, 'x2': 368, 'y1': 80, 'y2': 384, 'class': 'N95', 'prob': 0.99578637}]
# [0.99578637]
# IoU = 0.7241123273181812
# ...

# %%
# !python measure_map.py -p testMergedLabels.txt -o simple --model_path new_iou_result/model_frcnn_0019.hdf5
# Out:
# {0: 'no mask', 1: 'cloth', 2: 'N95', 3: 'surgical', 4: 'improper', 5: 'bg'}
# 2022-05-17 09:11:54.117721: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Loading weights from new_iou_result/model_frcnn_0019.hdf5
# Parsing annotation files
# idx=2041/197
# Elapsed time =  2.92850661277771
# [{'x1': 112, 'x2': 336, 'y1': 64, 'y2': 368, 'class': 'surgical', 'prob': 0.9507889}]
# [0.9507889]
# IoU = 0.7802904773777012
# surgical AP: 1.0
# mAP = 1.0
# 2/197
# Elapsed time =  0.5286514759063721
# [{'x1': 96, 'x2': 336, 'y1': 80, 'y2': 368, 'class': 'N95', 'prob': 0.9959753}]
# [0.9959753]
# IoU = 0.7856604394315029
# surgical AP: 1.0
# N95 AP: 1.0
# mAP = 1.0
# 3/197
# Elapsed time =  0.45843982696533203
# [{'x1': 96, 'x2': 320, 'y1': 96, 'y2': 384, 'class': 'N95', 'prob': 0.9936466}]
# [0.9936466]
# IoU = 0.7887680670528718
# surgical AP: 1.0
# ...

# %%
# !python measure_map.py -p testMergedLabels.txt -o simple --model_path new_iou_result/model_frcnn_0014.hdf5
# Out:
# {0: 'no mask', 1: 'cloth', 2: 'N95', 3: 'surgical', 4: 'improper', 5: 'bg'}
# 2022-05-17 09:14:04.294476: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Loading weights from new_iou_result/model_frcnn_0014.hdf5
# Parsing annotation files
# idx=2041/197
# Elapsed time =  2.7495884895324707
# [{'x1': 112, 'x2': 352, 'y1': 64, 'y2': 384, 'class': 'surgical', 'prob': 0.9988827}]
# [0.9988827]
# IoU = 0.8505831326630223
# surgical AP: 1.0
# mAP = 1.0
# 2/197
# Elapsed time =  0.43350934982299805
# [{'x1': 112, 'x2': 320, 'y1': 80, 'y2': 368, 'class': 'N95', 'prob': 0.995887}]
# [0.995887]
# IoU = 0.6835455159333284
# surgical AP: 1.0
# N95 AP: 1.0
# mAP = 1.0
# 3/197
# Elapsed time =  0.4521164894104004
# [{'x1': 112, 'x2': 336, 'y1': 96, 'y2': 368, 'class': 'N95', 'prob': 0.99935156}]
# [0.99935156]
# IoU = 0.7318176971289739
# surgical AP: 1.0
# ...

# %%
# !python measure_map.py -p testMergedLabels.txt -o simple --model_path new_iou_result/model_frcnn_0009.hdf5
# Out:
# {0: 'no mask', 1: 'cloth', 2: 'N95', 3: 'surgical', 4: 'improper', 5: 'bg'}
# 2022-05-17 09:16:10.582713: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Loading weights from new_iou_result/model_frcnn_0009.hdf5
# Parsing annotation files
# idx=2041/197
# Elapsed time =  2.727529287338257
# [{'x1': 80, 'x2': 336, 'y1': 64, 'y2': 384, 'class': 'surgical', 'prob': 0.9691516}]
# [0.9691516]
# IoU = 0.8064770857366435
# surgical AP: 1.0
# mAP = 1.0
# 2/197
# Elapsed time =  0.41126155853271484
# [{'x1': 80, 'x2': 320, 'y1': 80, 'y2': 352, 'class': 'N95', 'prob': 0.993725}]
# [0.993725]
# IoU = 0.7923169589886585
# surgical AP: 1.0
# N95 AP: 1.0
# mAP = 1.0
# 3/197
# Elapsed time =  0.3893604278564453
# [{'x1': 96, 'x2': 320, 'y1': 96, 'y2': 384, 'class': 'N95', 'prob': 0.98988473}]
# [0.98988473]
# IoU = 0.7887680670528718
# surgical AP: 1.0
# ...

# %%
# !python measure_map.py -p testMergedLabels.txt -o simple --model_path new_iou_result/model_frcnn_0004.hdf5
# Out:
# {0: 'no mask', 1: 'cloth', 2: 'N95', 3: 'surgical', 4: 'improper', 5: 'bg'}
# 2022-05-17 09:18:10.266015: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Loading weights from new_iou_result/model_frcnn_0004.hdf5
# Parsing annotation files
# idx=2041/197
# Elapsed time =  2.7872071266174316
# [{'x1': 80, 'x2': 352, 'y1': 48, 'y2': 384, 'class': 'surgical', 'prob': 0.96097285}]
# [0.96097285]
# IoU = 0.89476809101722
# surgical AP: 1.0
# mAP = 1.0
# 2/197
# Elapsed time =  0.463773250579834
# [{'x1': 128, 'x2': 352, 'y1': 80, 'y2': 368, 'class': 'N95', 'prob': 0.98020256}]
# [0.98020256]
# IoU = 0.7347017584774925
# surgical AP: 1.0
# N95 AP: 1.0
# mAP = 1.0
# 3/197
# Elapsed time =  0.40661120414733887
# [{'x1': 96, 'x2': 352, 'y1': 128, 'y2': 384, 'class': 'N95', 'prob': 0.9796622}]
# [0.9796622]
# IoU = 0.6613877687279437
# surgical AP: 1.0
# ...

# %%
# !python measure_map.py -p testMergedLabels.txt -o simple --model_path resnet50_result/model_frcnn_0000.hdf5
